# %%
def get_book(val):
    r = Book(identifier='isbn', identifier_value=val)
    r.extract_metadata()
    r.save()
# Out:
#   File "<tokenize>", line 3
#     r.extract_metadata()
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
with open("books.txt", 'r') as pf:
	dump=pf.readlines()
	count=0
	isbn=[]
	while(count<len(dump)):
		if "isbn=" in dump[count]:
			r = dump[count].strip().split('=')[1]
			isbn.append(r)
		count+=1

# %%
newsi = isbn[30:]

# %%
import threading
for val in newsi:
    threading._start_new_thread(get_book,(val,))
# Out:
# {'google_url': 'https://books.google.com/books/about/Head_First_Programming.html?hl=&id=E9K8Br6ZkKQC', 'description': 'Presents the concepts of writing computer programs, covering such topics as variables, loops, functions, data files and arrays, modular programming, widgets, exceptions, and objects.', 'tags': ['Computers'], 'cover': 'http://books.google.com/books/content?id=E9K8Br6ZkKQC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 'published_date': datetime.datetime(2009, 11, 23, 0, 0), 'publisher': '"O\'Reilly Media, Inc."', 'authors': 'David Griffiths,Paul Barry', 'page_count': 406, 'title': 'Head First Programming'}
# {'title': 'Head First Programming', 'subtitle': "A Learner's Guide to Programming Using the Python Language", 'authors': ['Paul Barry', 'David Griffiths'], 'publisher': '"O\'Reilly Media, Inc."', 'publishedDate': '2009-11-23', 'description': 'Presents the concepts of writing computer programs, covering such topics as variables, loops, functions, data files and arrays, modular programming, widgets, exceptions, and objects.', 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9780596802370'}, {'type': 'ISBN_10', 'identifier': '0596802374'}], 'readingModes': {'text': False, 'image': True}, 'pageCount': 406, 'printType': 'BOOK', 'categories': ['Computers'], 'averageRating': 4.0, 'ratingsCount': 3, 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': False, 'contentVersion': '2.4.0.0.preview.1', 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=E9K8Br6ZkKQC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=E9K8Br6ZkKQC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.co.in/books?id=E9K8Br6ZkKQC&printsec=frontcover&dq=isbn:0596802374&hl=&cd=1&source=gbs_api', 'infoLink': 'http://books.google.co.in/books?id=E9K8Br6ZkKQC&dq=isbn:0596802374&hl=&source=gbs_api', 'canonicalVolumeLink': 'https://books.google.com/books/about/Head_First_Programming.html?hl=&id=E9K8Br6ZkKQC'}
# {'google_url': 'https://market.android.com/details?id=book-URMJAgAAQBAJ', 'description': 'This book covers the fundamental concepts in signal processing illustrated with Python code and made available via IPython Notebooks, which are live, interactive, browser-based documents that allow one to change parameters, redraw plots, and tinker with the ideas presented in the text. Everything in the text is computable in this format and thereby invites readers to “experiment and learn” as they read. The book focuses on the core, fundamental principles of signal processing. The code corresponding to this book uses the core functionality of the scientific Python toolchain that should remain unchanged into the foreseeable future. For those looking to migrate their signal processing codes to Python, this book illustrates the key signal and plotting modules that can ease this transition. For those already comfortable with the scientific Python toolchain, this book illustrates the fundamental concepts in signal processing and provides a gateway to further signal processing concepts.', 'tags': ['Technology & Engineering'], 'cover': 'http://books.google.com/books/content?id=URMJAgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 'published_date': datetime.datetime(2013, 10, 4, 0, 0), 'publisher': 'Springer Science & Business Media', 'authors': 'José Unpingco', 'page_count': 128, 'title': 'Python for Signal Processing'}
# {'title': 'Python for Signal Processing', 'subtitle': 'Featuring IPython Notebooks', 'authors': ['José Unpingco'], 'publisher': 'Springer Science & Business Media', 'publishedDate': '2013-10-04', 'description': 'This book covers the fundamental concepts in signal processing illustrated with Python code and made available via IPython Notebooks, which are live, interactive, browser-based documents that allow one to change parameters, redraw plots, and tinker with the ideas presented in the text. Everything in the text is computable in this format and thereby invites readers to “experiment and learn” as they read. The book focuses on the core, fundamental principles of signal processing. The code corresponding to this book uses the core functionality of the scientific Python toolchain that should remain unchanged into the foreseeable future. For those looking to migrate their signal processing codes to Python, this book illustrates the key signal and plotting modules that can ease this transition. For those already comfortable with the scientific Python toolchain, this book illustrates the fundamental concepts in signal processing and provides a gateway to further signal processing concepts.', 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9783319013428'}, {'type': 'ISBN_10', 'identifier': '3319013424'}], 'readingModes': {'text': True, 'image': True}, 'pageCount': 128, 'printType': 'BOOK', 'categories': ['Technology & Engineering'], 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': False, 'contentVersion': '2.11.9.0.preview.3', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=URMJAgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=URMJAgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.co.in/books?id=URMJAgAAQBAJ&printsec=frontcover&dq=isbn:3319013424&hl=&cd=1&source=gbs_api', 'infoLink': 'https://play.google.com/store/books/details?id=URMJAgAAQBAJ&source=gbs_api', 'canonicalVolumeLink': 'https://market.android.com/details?id=book-URMJAgAAQBAJ'}
# {'google_url': 'https://books.google.com/books/about/Python_101.html?hl=&id=eqfIBgAAQBAJ', 'description': 'Learn how to program with Python from beginning to end. This book is for beginners who want to get up to speed quickly and become intermediate programmers fast!', 'tags': None, 'cover': 'http://books.google.com/books/content?id=eqfIBgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 'published_date': datetime.datetime(2014, 6, 3, 0, 0), 'publisher': 'Lulu.com', 'authors': 'Michael Driscoll', 'page_count': 239, 'title': 'Python 101'}
# {'title': 'Python 101', 'authors': ['Michael Driscoll'], 'publisher': 'Lulu.com', 'publishedDate': '2014-06-03', 'description': 'Learn how to program with Python from beginning to end. This book is for beginners who want to get up to speed quickly and become intermediate programmers fast!', 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9780996062817'}, {'type': 'ISBN_10', 'identifier': '0996062815'}], 'readingModes': {'text': False, 'image': True}, 'pageCount': 239, 'printType': 'BOOK', 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': False, 'contentVersion': '0.1.1.0.preview.1', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=eqfIBgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=eqfIBgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.co.in/books?id=eqfIBgAAQBAJ&printsec=frontcover&dq=isbn:0996062815&hl=&cd=1&source=gbs_api', 'infoLink': 'http://books.google.co.in/books?id=eqfIBgAAQBAJ&dq=isbn:0996062815&hl=&source=gbs_api', 'canonicalVolumeLink': 'https://books.google.com/books/about/Python_101.html?hl=&id=eqfIBgAAQBAJ'}
# {'google_url': 'https://market.android.com/details?id=book-G_mrBwAAQBAJ', 'description': "This book primarily targets Python developers who want to learn and use Python's machine learning capabilities and gain valuable insights from data to develop effective solutions for business problems.", 'tags': ['Computers'], 'cover': 'http://books.google.com/books/content?id=G_mrBwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 'published_date': datetime.datetime(2015, 3, 26, 0, 0), 'publisher': 'Packt Publishing Ltd', 'authors': 'Willi Richert,Luis Pedro Coelho', 'page_count': 326, 'title': 'Building Machine Learning Systems with Python - Second Edition'}
# {'title': 'Building Machine Learning Systems with Python - Second Edition', 'authors': ['Luis Pedro Coelho', 'Willi Richert'], 'publisher': 'Packt Publishing Ltd', 'publishedDate': '2015-03-26', 'description': "This book primarily targets Python developers who want to learn and use Python's machine learning capabilities and gain valuable insights from data to develop effective solutions for business problems.", 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781784392888'}, {'type': 'ISBN_10', 'identifier': '178439288X'}], 'readingModes': {'text': True, 'image': True}, 'pageCount': 326, 'printType': 'BOOK', 'categories': ['Computers'], 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': True, 'contentVersion': '2.2.2.0.preview.3', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=G_mrBwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=G_mrBwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.co.in/books?id=G_mrBwAAQBAJ&printsec=frontcover&dq=isbn:178439288X&hl=&cd=1&source=gbs_api', 'infoLink': 'https://play.google.com/store/books/details?id=G_mrBwAAQBAJ&source=gbs_api', 'canonicalVolumeLink': 'https://market.android.com/details?id=book-G_mrBwAAQBAJ'}
# {'google_url': 'https://market.android.com/details?id=book-gDQH1urIDqUC', 'description': 'Create, optimize, and deploy stunning cross-browser web maps with the OpenLayers JavaScript web mapping library.', 'tags': ['Computers'], 'cover': 'http://books.google.com/books/content?id=gDQH1urIDqUC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 'published_date': datetime.datetime(2011, 3, 18, 0, 0), 'publisher': 'Packt Publishing Ltd', 'authors': 'Erik Hazzard', 'page_count': 372, 'title': "OpenLayers 2.10 Beginner's Guide"}
# {'title': "OpenLayers 2.10 Beginner's Guide", 'authors': ['Erik Hazzard'], 'publisher': 'Packt Publishing Ltd', 'publishedDate': '2011-03-18', 'description': 'Create, optimize, and deploy stunning cross-browser web maps with the OpenLayers JavaScript web mapping library.', 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781849514132'}, {'type': 'ISBN_10', 'identifier': '1849514135'}], 'readingModes': {'text': True, 'image': True}, 'pageCount': 372, 'printType': 'BOOK', 'categories': ['Computers'], 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': True, 'contentVersion': '2.3.3.0.preview.3', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=gDQH1urIDqUC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=gDQH1urIDqUC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.co.in/books?id=gDQH1urIDqUC&printsec=frontcover&dq=isbn:1849514135&hl=&cd=1&source=gbs_api', 'infoLink': 'https://play.google.com/store/books/details?id=gDQH1urIDqUC&source=gbs_api', 'canonicalVolumeLink': 'https://market.android.com/details?id=book-gDQH1urIDqUC'}
# {'google_url': 'https://books.google.com/books/about/Python_Data_Structures_and_Algorithm.html?hl=&id=aerzvQAACAAJ', 'description': 'Implement classic and functional data structures and algorithms using PythonAbout This Book* The book will teach you how to use data structures such as arrays, stacks, trees, lists and graphs with real-world examples.* Learn important and advanced data structures such as searching and sorting algorithms.* Understand important concepts such as big-o notation, dynamic programming, and functional data structures.Who This Book Is ForThe book will appeal to Python developers. A basic knowledge of Python is expected.What You Will Learn* Gain a solid understanding of Python data structures.* Build sophisticated data applications.* Understand the common programming patterns and algorithms used in Python data science.* Write efficient robust code.In DetailData structures allow you to organize data in a particular way efficiently. They are critical to any problem, provide a complete solution, and act like reusable code.In this book you will learn the essential Python data structures and the most common algorithms. With this easy-to-read book, you will be able to understand the power of linked lists, double linked lists, and circular linked lists. You will be able to create complex data structures such as graphs, stacks and queues. We will explore the application of binary searches and binary search trees. You will learn the common techniques and structures used in tasks such as preprocessing, modeling, and transforming data. We will also discuss how to organize your code in a manageable, consistent, and extendable way. The book will explore in detail sorting algorithms such as bubble sort, selection sort, insertion sort, and merge sort.By the end of the book you will learn how to build components that are easy to understand, debug, and use in different applications.', 'tags': None, 'cover': 'http://books.google.com/books/content?id=aerzvQAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 'published_date': datetime.datetime(2017, 4, 28, 0, 0), 'publisher': None, 'authors': 'David Julian', 'page_count': 377, 'title': 'Python Data Structures and Algorithm'}
# {'title': 'Python Data Structures and Algorithm', 'authors': ['David Julian'], 'publishedDate': '2017-04-28', 'description': 'Implement classic and functional data structures and algorithms using PythonAbout This Book* The book will teach you how to use data structures such as arrays, stacks, trees, lists and graphs with real-world examples.* Learn important and advanced data structures such as searching and sorting algorithms.* Understand important concepts such as big-o notation, dynamic programming, and functional data structures.Who This Book Is ForThe book will appeal to Python developers. A basic knowledge of Python is expected.What You Will Learn* Gain a solid understanding of Python data structures.* Build sophisticated data applications.* Understand the common programming patterns and algorithms used in Python data science.* Write efficient robust code.In DetailData structures allow you to organize data in a particular way efficiently. They are critical to any problem, provide a complete solution, and act like reusable code.In this book you will learn the essential Python data structures and the most common algorithms. With this easy-to-read book, you will be able to understand the power of linked lists, double linked lists, and circular linked lists. You will be able to create complex data structures such as graphs, stacks and queues. We will explore the application of binary searches and binary search trees. You will learn the common techniques and structures used in tasks such as preprocessing, modeling, and transforming data. We will also discuss how to organize your code in a manageable, consistent, and extendable way. The book will explore in detail sorting algorithms such as bubble sort, selection sort, insertion sort, and merge sort.By the end of the book you will learn how to build components that are easy to understand, debug, and use in different applications.', 'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '1786467356'}, {'type': 'ISBN_13', 'identifier': '9781786467355'}], 'readingModes': {'text': False, 'image': False}, 'pageCount': 377, 'printType': 'BOOK', 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': False, 'contentVersion': 'preview-1.0.0', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=aerzvQAACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=aerzvQAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.co.in/books?id=aerzvQAACAAJ&dq=isbn:1786467356&hl=&cd=1&source=gbs_api', 'infoLink': 'http://books.google.co.in/books?id=aerzvQAACAAJ&dq=isbn:1786467356&hl=&source=gbs_api', 'canonicalVolumeLink': 'https://books.google.com/books/about/Python_Data_Structures_and_Algorithm.html?hl=&id=aerzvQAACAAJ'}
# {'google_url': 'https://market.android.com/details?id=book-O1AoDwAAQBAJ', 'description': "Build real-world Artificial Intelligence applications with Python to intelligently interact with the world around you About This Book Step into the amazing world of intelligent apps using this comprehensive guide Enter the world of Artificial Intelligence, explore it, and create your own applications Work through simple yet insightful examples that will get you up and running with Artificial Intelligence in no time Who This Book Is For This book is for Python developers who want to build real-world Artificial Intelligence applications. This book is friendly to Python beginners, but being familiar with Python would be useful to play around with the code. It will also be useful for experienced Python programmers who are looking to use Artificial Intelligence techniques in their existing technology stacks. What You Will Learn Realize different classification and regression techniques Understand the concept of clustering and how to use it to automatically segment data See how to build an intelligent recommender system Understand logic programming and how to use it Build automatic speech recognition systems Understand the basics of heuristic search and genetic programming Develop games using Artificial Intelligence Learn how reinforcement learning works Discover how to build intelligent applications centered on images, text, and time series data See how to use deep learning algorithms and build applications based on it In Detail Artificial Intelligence is becoming increasingly relevant in the modern world where everything is driven by technology and data. It is used extensively across many fields such as search engines, image recognition, robotics, finance, and so on. We will explore various real-world scenarios in this book and you'll learn about various algorithms that can be used to build Artificial Intelligence applications. During the course of this book, you will find out how to make informed decisions about what algorithms to use in a given context. Starting from the basics of Artificial Intelligence, you will learn how to develop various building blocks using different data mining techniques. You will see how to implement different algorithms to get the best possible results, and will understand how to apply them to real-world scenarios. If you want to add an intelligence layer to any application that's based on images, text, stock market, or some other form of data, this exciting book on Artificial Intelligence will definitely be your guide! Style and approach This highly practical book will show you how to implement Artificial Intelligence. The book provides multiple examples enabling you to create smart applications to meet the needs of your organization. In every chapter, we explain an algorithm, implement it, and then build a smart application.", 'tags': ['Computers'], 'cover': 'http://books.google.com/books/content?id=O1AoDwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 'published_date': datetime.datetime(2017, 1, 27, 0, 0), 'publisher': 'Packt Publishing Ltd', 'authors': 'Prateek Joshi', 'page_count': 446, 'title': 'Artificial Intelligence with Python'}
# {'title': 'Artificial Intelligence with Python', 'authors': ['Prateek Joshi'], 'publisher': 'Packt Publishing Ltd', 'publishedDate': '2017-01-27', 'description': "Build real-world Artificial Intelligence applications with Python to intelligently interact with the world around you About This Book Step into the amazing world of intelligent apps using this comprehensive guide Enter the world of Artificial Intelligence, explore it, and create your own applications Work through simple yet insightful examples that will get you up and running with Artificial Intelligence in no time Who This Book Is For This book is for Python developers who want to build real-world Artificial Intelligence applications. This book is friendly to Python beginners, but being familiar with Python would be useful to play around with the code. It will also be useful for experienced Python programmers who are looking to use Artificial Intelligence techniques in their existing technology stacks. What You Will Learn Realize different classification and regression techniques Understand the concept of clustering and how to use it to automatically segment data See how to build an intelligent recommender system Understand logic programming and how to use it Build automatic speech recognition systems Understand the basics of heuristic search and genetic programming Develop games using Artificial Intelligence Learn how reinforcement learning works Discover how to build intelligent applications centered on images, text, and time series data See how to use deep learning algorithms and build applications based on it In Detail Artificial Intelligence is becoming increasingly relevant in the modern world where everything is driven by technology and data. It is used extensively across many fields such as search engines, image recognition, robotics, finance, and so on. We will explore various real-world scenarios in this book and you'll learn about various algorithms that can be used to build Artificial Intelligence applications. During the course of this book, you will find out how to make informed decisions about what algorithms to use in a given context. Starting from the basics of Artificial Intelligence, you will learn how to develop various building blocks using different data mining techniques. You will see how to implement different algorithms to get the best possible results, and will understand how to apply them to real-world scenarios. If you want to add an intelligence layer to any application that's based on images, text, stock market, or some other form of data, this exciting book on Artificial Intelligence will definitely be your guide! Style and approach This highly practical book will show you how to implement Artificial Intelligence. The book provides multiple examples enabling you to create smart applications to meet the needs of your organization. In every chapter, we explain an algorithm, implement it, and then build a smart application.", 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781786469670'}, {'type': 'ISBN_10', 'identifier': '1786469677'}], 'readingModes': {'text': True, 'image': True}, 'pageCount': 446, 'printType': 'BOOK', 'categories': ['Computers'], 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': True, 'contentVersion': '2.2.2.0.preview.3', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=O1AoDwAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=O1AoDwAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.co.in/books?id=O1AoDwAAQBAJ&printsec=frontcover&dq=isbn:1786469677&hl=&cd=1&source=gbs_api', 'infoLink': 'https://play.google.com/store/books/details?id=O1AoDwAAQBAJ&source=gbs_api', 'canonicalVolumeLink': 'https://market.android.com/details?id=book-O1AoDwAAQBAJ'}
# {'google_url': 'https://market.android.com/details?id=book-6ErrBgAAQBAJ', 'description': "Maya Python for Games and Film is the first book to focus exclusively on how to implement Python with Maya. Written by trusted authorities in the field, this in-depth guide will help you master Maya Python, whether you're a seasoned technical artist looking to make the transition from MEL to Python or an aspiring artist not wanting to scramble for information.", 'tags': ['Computers'], 'cover': 'http://books.google.com/books/content?id=6ErrBgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 'published_date': datetime.datetime(2011, 9, 28, 0, 0), 'publisher': 'CRC Press', 'authors': 'Ryan Trowbridge,Adam Mechtley', 'page_count': 408, 'title': 'Maya Python for Games and Film'}
# {'title': 'Maya Python for Games and Film', 'subtitle': 'A Complete Reference for Maya Python and the Maya Python API', 'authors': ['Adam Mechtley', 'Ryan Trowbridge'], 'publisher': 'CRC Press', 'publishedDate': '2011-09-28', 'description': "Maya Python for Games and Film is the first book to focus exclusively on how to implement Python with Maya. Written by trusted authorities in the field, this in-depth guide will help you master Maya Python, whether you're a seasoned technical artist looking to make the transition from MEL to Python or an aspiring artist not wanting to scramble for information.", 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9780123785794'}, {'type': 'ISBN_10', 'identifier': '0123785790'}], 'readingModes': {'text': False, 'image': True}, 'pageCount': 408, 'printType': 'BOOK', 'categories': ['Computers'], 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': True, 'contentVersion': 'preview-1.0.0', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=6ErrBgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=6ErrBgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.co.in/books?id=6ErrBgAAQBAJ&printsec=frontcover&dq=isbn:0123785790&hl=&cd=1&source=gbs_api', 'infoLink': 'https://play.google.com/store/books/details?id=6ErrBgAAQBAJ&source=gbs_api', 'canonicalVolumeLink': 'https://market.android.com/details?id=book-6ErrBgAAQBAJ'}
# {'google_url': 'https://books.google.com/books/about/MongoDB_in_Action.html?hl=&id=iR7VcQAACAAJ', 'description': 'This comprehensive guide book begins by explaining what makes MongoDB unique. A series of tutorials designed for MongoDB mastery then leads into detailed examples for leveraging MongoDB in e-commerce, social networking, analytics, and other common applications.', 'tags': ['Computers'], 'cover': 'http://books.google.com/books/content?id=iR7VcQAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 'published_date': datetime.datetime(2012, 1, 8, 0, 0), 'publisher': 'Manning Publications', 'authors': 'Kyle Banker', 'page_count': 287, 'title': 'MongoDB in Action'}
# {'title': 'MongoDB in Action', 'authors': ['Kyle Banker'], 'publisher': 'Manning Publications', 'publishedDate': '2012-01', 'description': 'This comprehensive guide book begins by explaining what makes MongoDB unique. A series of tutorials designed for MongoDB mastery then leads into detailed examples for leveraging MongoDB in e-commerce, social networking, analytics, and other common applications.', 'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '1935182870'}, {'type': 'ISBN_13', 'identifier': '9781935182870'}], 'readingModes': {'text': False, 'image': False}, 'pageCount': 287, 'printType': 'BOOK', 'categories': ['Computers'], 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': False, 'contentVersion': 'preview-1.0.0', 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=iR7VcQAACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=iR7VcQAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.co.in/books?id=iR7VcQAACAAJ&dq=isbn:1935182870&hl=&cd=1&source=gbs_api', 'infoLink': 'http://books.google.co.in/books?id=iR7VcQAACAAJ&dq=isbn:1935182870&hl=&source=gbs_api', 'canonicalVolumeLink': 'https://books.google.com/books/about/MongoDB_in_Action.html?hl=&id=iR7VcQAACAAJ'}
# {'google_url': 'https://books.google.com/books/about/Data_Structures_and_Algorithms_Made_Easy.html?hl=&id=LIUQvgAACAAJ', 'description': '"Data Structures And Algorithms Made Easy: Data Structures and Algorithmic Puzzles" is a book that offers solutions to complex data structures and algorithms. There are multiple solutions for each problem and the book is coded in C/C++, it comes handy as an interview and exam guide for computer scientists.', 'tags': ['Business & Economics'], 'cover': 'http://books.google.com/books/content?id=LIUQvgAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 'published_date': datetime.datetime(2016, 8, 28, 0, 0), 'publisher': 'Careermonk Publications', 'authors': 'Narasimha Karumanchi', 'page_count': 434, 'title': 'Data Structures and Algorithms Made Easy'}
# {'title': 'Data Structures and Algorithms Made Easy', 'subtitle': 'Data Structures and Algorithmic Puzzles', 'authors': ['Narasimha Karumanchi'], 'publisher': 'Careermonk Publications', 'publishedDate': '2016-08-28', 'description': '"Data Structures And Algorithms Made Easy: Data Structures and Algorithmic Puzzles" is a book that offers solutions to complex data structures and algorithms. There are multiple solutions for each problem and the book is coded in C/C++, it comes handy as an interview and exam guide for computer scientists.', 'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '819324527X'}, {'type': 'ISBN_13', 'identifier': '9788193245279'}], 'readingModes': {'text': False, 'image': False}, 'pageCount': 434, 'printType': 'BOOK', 'categories': ['Business & Economics'], 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': False, 'contentVersion': 'preview-1.0.0', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=LIUQvgAACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=LIUQvgAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.co.in/books?id=LIUQvgAACAAJ&dq=isbn:819324527X&hl=&cd=1&source=gbs_api', 'infoLink': 'http://books.google.co.in/books?id=LIUQvgAACAAJ&dq=isbn:819324527X&hl=&source=gbs_api', 'canonicalVolumeLink': 'https://books.google.com/books/about/Data_Structures_and_Algorithms_Made_Easy.html?hl=&id=LIUQvgAACAAJ'}
# {'google_url': 'https://books.google.com/books/about/The_Quick_Python_Book.html?hl=&id=RyoNBQAAQBAJ', 'description': 'The Quick Python Book, Second Edition, is a clear, concise introduction to Python 3, aimed at programmers new to Python. This updated edition includes all the changes in Python 3, itself a significant shift from earlier versions of Python. The book begins with basic but useful programs that teach the core features of syntax, control flow, and data structures. It then moves to larger applications involving code management, object-oriented programming, web development, and converting code from earlier versions of Python. True to his audience of experienced developers, the author covers common programming language features concisely, while giving more detail to those features unique to Python. Purchase of the print book comes with an offer of a free PDF, ePub, and Kindle eBook from Manning. Also available is all code from the book.', 'tags': ['Computers'], 'cover': 'http://books.google.com/books/content?id=RyoNBQAAQBAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 'published_date': datetime.datetime(2010, 1, 15, 0, 0), 'publisher': 'Manning Publications; 2nd edition (January 15, 2010)', 'authors': 'Naomi R. Ceder', 'page_count': 362, 'title': 'The Quick Python Book'}
# {'title': 'The Quick Python Book', 'subtitle': 'Second Edition', 'authors': ['Naomi R. Ceder'], 'publisher': 'Manning Publications; 2nd edition (January 15, 2010)', 'publishedDate': '2010-01-15', 'description': 'The Quick Python Book, Second Edition, is a clear, concise introduction to Python 3, aimed at programmers new to Python. This updated edition includes all the changes in Python 3, itself a significant shift from earlier versions of Python. The book begins with basic but useful programs that teach the core features of syntax, control flow, and data structures. It then moves to larger applications involving code management, object-oriented programming, web development, and converting code from earlier versions of Python. True to his audience of experienced developers, the author covers common programming language features concisely, while giving more detail to those features unique to Python. Purchase of the print book comes with an offer of a free PDF, ePub, and Kindle eBook from Manning. Also available is all code from the book.', 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781935182207'}, {'type': 'ISBN_10', 'identifier': '193518220X'}], 'readingModes': {'text': False, 'image': False}, 'pageCount': 362, 'printType': 'BOOK', 'categories': ['Computers'], 'averageRating': 4.0, 'ratingsCount': 1, 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': False, 'contentVersion': 'preview-1.0.0', 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=RyoNBQAAQBAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=RyoNBQAAQBAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.co.in/books?id=RyoNBQAAQBAJ&dq=isbn:193518220X&hl=&cd=1&source=gbs_api', 'infoLink': 'http://books.google.co.in/books?id=RyoNBQAAQBAJ&dq=isbn:193518220X&hl=&source=gbs_api', 'canonicalVolumeLink': 'https://books.google.com/books/about/The_Quick_Python_Book.html?hl=&id=RyoNBQAAQBAJ'}{'google_url': 'https://books.google.com/books/about/Think_Java.html?hl=&id=XYQpDAAAQBAJ', 'description': 'Currently used at many colleges, universities, and high schools, this hands-on introduction to computer science is ideal for people with little or no programming experience. The goal of this concise book is not just to teach you Java, but to help you think like a computer scientist. You’ll learn how to program—a useful skill by itself—but you’ll also discover how to use programming as a means to an end. Authors Allen Downey and Chris Mayfield start with the most basic concepts and gradually move into topics that are more complex, such as recursion and object-oriented programming. Each brief chapter covers the material for one week of a college course and includes exercises to help you practice what you’ve learned. Learn one concept at a time: tackle complex topics in a series of small steps with examples Understand how to formulate problems, think creatively about solutions, and write programs clearly and accurately Determine which development techniques work best for you, and practice the important skill of debugging Learn relationships among input and output, decisions and loops, classes and methods, strings and arrays Work on exercises involving word games, graphics, puzzles, and playing cards', 'tags': ['Computers'], 'cover': 'http://books.google.com/books/content?id=XYQpDAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 'published_date': datetime.datetime(2016, 5, 6, 0, 0), 'publisher': '"O\'Reilly Media, Inc."', 'authors': 'Chris Mayfield,Allen B. Downey', 'page_count': 252, 'title': 'Think Java'}
#
# {'title': 'Think Java', 'subtitle': 'How to Think Like a Computer Scientist', 'authors': ['Allen B. Downey', 'Chris Mayfield'], 'publisher': '"O\'Reilly Media, Inc."', 'publishedDate': '2016-05-06', 'description': 'Currently used at many colleges, universities, and high schools, this hands-on introduction to computer science is ideal for people with little or no programming experience. The goal of this concise book is not just to teach you Java, but to help you think like a computer scientist. You’ll learn how to program—a useful skill by itself—but you’ll also discover how to use programming as a means to an end. Authors Allen Downey and Chris Mayfield start with the most basic concepts and gradually move into topics that are more complex, such as recursion and object-oriented programming. Each brief chapter covers the material for one week of a college course and includes exercises to help you practice what you’ve learned. Learn one concept at a time: tackle complex topics in a series of small steps with examples Understand how to formulate problems, think creatively about solutions, and write programs clearly and accurately Determine which development techniques work best for you, and practice the important skill of debugging Learn relationships among input and output, decisions and loops, classes and methods, strings and arrays Work on exercises involving word games, graphics, puzzles, and playing cards', 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781491929537'}, {'type': 'ISBN_10', 'identifier': '1491929537'}], 'readingModes': {'text': False, 'image': True}, 'pageCount': 252, 'printType': 'BOOK', 'categories': ['Computers'], 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': False, 'contentVersion': '0.2.0.0.preview.1', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=XYQpDAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=XYQpDAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.co.in/books?id=XYQpDAAAQBAJ&pg=PP1&dq=isbn:1491929537&hl=&cd=1&source=gbs_api', 'infoLink': 'http://books.google.co.in/books?id=XYQpDAAAQBAJ&dq=isbn:1491929537&hl=&source=gbs_api', 'canonicalVolumeLink': 'https://books.google.com/books/about/Think_Java.html?hl=&id=XYQpDAAAQBAJ'}
# {'google_url': 'https://books.google.com/books/about/Hacking_Secret_Ciphers_with_Python.html?hl=&id=OMZFmwEACAAJ', 'description': "Hacking Secret Ciphers with Python not only teaches you how to write in secret ciphers with paper and pencil. This book teaches you how to write your own cipher programs and also the hacking programs that can break the encrypted messages from these ciphers. Unfortunately, the programs in this book won't get the reader in trouble with the law (or rather, fortunately) but it is a guide on the basics of both cryptography and the Python programming language. Instead of presenting a dull laundry list of concepts, this book provides the source code to several fun programming projects for adults and young adults.", 'tags': ['Computers'], 'cover': 'http://books.google.com/books/content?id=OMZFmwEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 'published_date': datetime.datetime(2013, 4, 1, 0, 0), 'publisher': 'Createspace Independent Pub', 'authors': 'Al Sweigart', 'page_count': 416, 'title': 'Hacking Secret Ciphers with Python'}{'google_url': 'https://books.google.com/books/about/Data_Science_from_Scratch.html?hl=&id=JYodCAAAQBAJ', 'description': "Data science libraries, frameworks, modules, and toolkits are great for doing data science, but they’re also a good way to dive into the discipline without actually understanding data science. In this book, you’ll learn how many of the most fundamental data science tools and algorithms work by implementing them from scratch. If you have an aptitude for mathematics and some programming skills, author Joel Grus will help you get comfortable with the math and statistics at the core of data science, and with hacking skills you need to get started as a data scientist. Today’s messy glut of data holds answers to questions no one’s even thought to ask. This book provides you with the know-how to dig those answers out. Get a crash course in Python Learn the basics of linear algebra, statistics, and probability—and understand how and when they're used in data science Collect, explore, clean, munge, and manipulate data Dive into the fundamentals of machine learning Implement models such as k-nearest Neighbors, Naive Bayes, linear and logistic regression, decision trees, neural networks, and clustering Explore recommender systems, natural language processing, network analysis, MapReduce, and databases", 'tags': ['BUSINESS & ECONOMICS'], 'cover': 'http://books.google.com/books/content?id=JYodCAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 'published_date': datetime.datetime(2015, 4, 14, 0, 0), 'publisher': '"O\'Reilly Media, Inc."', 'authors': 'Joel Grus', 'page_count': 330, 'title': 'Data Science from Scratch'}
#
# {'title': 'Data Science from Scratch', 'subtitle': 'First Principles with Python', 'authors': ['Joel Grus'], 'publisher': '"O\'Reilly Media, Inc."', 'publishedDate': '2015-04-14', 'description': "Data science libraries, frameworks, modules, and toolkits are great for doing data science, but they’re also a good way to dive into the discipline without actually understanding data science. In this book, you’ll learn how many of the most fundamental data science tools and algorithms work by implementing them from scratch. If you have an aptitude for mathematics and some programming skills, author Joel Grus will help you get comfortable with the math and statistics at the core of data science, and with hacking skills you need to get started as a data scientist. Today’s messy glut of data holds answers to questions no one’s even thought to ask. This book provides you with the know-how to dig those answers out. Get a crash course in Python Learn the basics of linear algebra, statistics, and probability—and understand how and when they're used in data science Collect, explore, clean, munge, and manipulate data Dive into the fundamentals of machine learning Implement models such as k-nearest Neighbors, Naive Bayes, linear and logistic regression, decision trees, neural networks, and clustering Explore recommender systems, natural language processing, network analysis, MapReduce, and databases", 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781491904404'}, {'type': 'ISBN_10', 'identifier': '1491904402'}], 'readingModes': {'text': False, 'image': True}, 'pageCount': 330, 'printType': 'BOOK', 'categories': ['BUSINESS & ECONOMICS'], 'averageRating': 3.0, 'ratingsCount': 3, 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': False, 'contentVersion': '0.2.0.0.preview.1', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=JYodCAAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=JYodCAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.co.in/books?id=JYodCAAAQBAJ&pg=PP1&dq=isbn:1491904402&hl=&cd=1&source=gbs_api', 'infoLink': 'http://books.google.co.in/books?id=JYodCAAAQBAJ&dq=isbn:1491904402&hl=&source=gbs_api', 'canonicalVolumeLink': 'https://books.google.com/books/about/Data_Science_from_Scratch.html?hl=&id=JYodCAAAQBAJ'}{'title': 'Hacking Secret Ciphers with Python', 'authors': ['Al Sweigart'], 'publisher': 'Createspace Independent Pub', 'publishedDate': '2013-04-01', 'description': "Hacking Secret Ciphers with Python not only teaches you how to write in secret ciphers with paper and pencil. This book teaches you how to write your own cipher programs and also the hacking programs that can break the encrypted messages from these ciphers. Unfortunately, the programs in this book won't get the reader in trouble with the law (or rather, fortunately) but it is a guide on the basics of both cryptography and the Python programming language. Instead of presenting a dull laundry list of concepts, this book provides the source code to several fun programming projects for adults and young adults.", 'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '1482614375'}, {'type': 'ISBN_13', 'identifier': '9781482614374'}], 'readingModes': {'text': False, 'image': False}, 'pageCount': 416, 'printType': 'BOOK', 'categories': ['Computers'], 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': False, 'contentVersion': 'preview-1.0.0', 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=OMZFmwEACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=OMZFmwEACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.co.in/books?id=OMZFmwEACAAJ&dq=isbn:1482614375&hl=&cd=1&so ...
#
# {'google_url': 'https://market.android.com/details?id=book-XUqqCAAAQBAJ', 'description': '" .. .1 always worked with programming languages because it seemed to me that until you could understand those, you really couldn\'t understand computers. Understanding them doesn\'t really mean only being able to use them. A lot of people can use them without understanding them." Christopher Strachey The development of programming languages is one of the finest intellectual achievements of the new discipline called Computer Science. And yet, there is no other subject that I know of, that has such emotionalism and mystique associated with it. Thus my attempt to write about this highly charged subject is taken with a good deal of caution. Nevertheless, in my role as Professor I have felt the need for a modern treatment of this subject. Traditional books on programming languages are like abbreviated language manuals, but this book takes a fundamentally different point of view. I believe that the best possible way to study and understand today\'s programming languages is by focusing on a few essential concepts. These concepts form the outline for this book and include such topics as variables, expressions, statements, typing, scope, procedures, data types, exception handling and concurrency. By understanding what these concepts are and how they are realized in different programming languages, one arrives at a level of comprehension far greater than one gets by writing some programs in a vi vB Preface few languages. Moreover, knowledge of these concepts provides a framework for understanding future language designs.', 'tags': ['Computers'], 'cover': 'http://books.google.com/books/content?id=XUqqCAAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 'published_date': datetime.datetime(2012, 12, 6, 0, 0), 'publisher': 'Springer Science & Business Media', 'authors': 'E. Horowitz', 'page_count': None, 'title': 'Fundamentals of Programming Languages'}
# ...
# {'google_url': 'https://market.android.com/details?id=book-yxZOBQAAQBAJ', 'description': 'Easy to understand and fun to read, Introducing Python is ideal for beginning programmers as well as those new to the language. Author Bill Lubanovic takes you from the basics to more involved and varied topics, mixing tutorials with cookbook-style code recipes to explain concepts in Python 3. End-of-chapter exercises help you practice what you’ve learned. You’ll gain a strong foundation in the language, including best practices for testing, debugging, code reuse, and other development tips. This book also shows you how to use Python for applications in business, science, and the arts, using various Python tools and open source packages. Learn simple data types, and basic math and text operations Use data-wrangling techniques with Python’s built-in data structures Explore Python code structure, including the use of functions Write large programs in Python, with modules and packages Dive into objects, classes, and other object-oriented features Examine storage from flat files to relational databases and NoSQL Use Python to build web clients, servers, APIs, and services Manage system tasks such as programs, processes, and threads Understand the basics of concurrency and network programming', 'tags': ['Computers'], 'cover': 'http://books.google.com/books/content?id=yxZOBQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 'published_date': datetime.datetime(2014, 11, 11, 0, 0), 'publisher': '"O\'Reilly Media, Inc."', 'authors': 'Bill Lubanovic', 'page_count': 484, 'title': 'Introducing Python'}
# {'title': 'Introducing Python', 'subtitle': 'Modern Computing in Simple Packages', 'authors': ['Bill Lubanovic'], 'publisher': '"O\'Reilly Media, Inc."', 'publishedDate': '2014-11-11', 'description': 'Easy to understand and fun to read, Introducing Python is ideal for beginning programmers as well as those new to the language. Author Bill Lubanovic takes you from the basics to more involved and varied topics, mixing tutorials with cookbook-style code recipes to explain concepts in Python 3. End-of-chapter exercises help you practice what you’ve learned. You’ll gain a strong foundation in the language, including best practices for testing, debugging, code reuse, and other development tips. This book also shows you how to use Python for applications in business, science, and the arts, using various Python tools and open source packages. Learn simple data types, and basic math and text operations Use data-wrangling techniques with Python’s built-in data structures Explore Python code structure, including the use of functions Write large programs in Python, with modules and packages Dive into objects, classes, and other object-oriented features Examine storage from flat files to relational databases and NoSQL Use Python to build web clients, servers, APIs, and services Manage system tasks such as programs, processes, and threads Understand the basics of concurrency and network programming', 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781449361181'}, {'type': 'ISBN_10', 'identifier': '1449361188'}], 'readingModes': {'text': True, 'image': True}, 'pageCount': 484, 'printType': 'BOOK', 'categories': ['Computers'], 'averageRating': 5.0, 'ratingsCount': 1, 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': True, 'contentVersion': '1.2.2.0.preview.3', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=yxZOBQAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=yxZOBQAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.co.in/books?id=yxZOBQAAQBAJ&printsec=frontcover&dq=isbn:1449361188&hl=&cd=1&source=gbs_api', 'infoLink': 'https://play.google.com/store/books/details?id=yxZOBQAAQBAJ&source=gbs_api', 'canonicalVolumeLink': 'https://market.android.com/details?id=book-yxZOBQAAQBAJ'}
# {'google_url': 'https://market.android.com/details?id=book-9G9zX_jf1f8C', 'description': 'Best practices for designing, coding, and distributing your Python software.', 'tags': ['Computers'], 'cover': 'http://books.google.com/books/content?id=9G9zX_jf1f8C&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 'published_date': datetime.datetime(2008, 9, 19, 0, 0), 'publisher': 'Packt Publishing Ltd', 'authors': 'Tarek Ziade', 'page_count': 373, 'title': 'Expert Python Programming'}
# {'title': 'Expert Python Programming', 'authors': ['Tarek Ziade'], 'publisher': 'Packt Publishing Ltd', 'publishedDate': '2008-09-19', 'description': 'Best practices for designing, coding, and distributing your Python software.', 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781847194954'}, {'type': 'ISBN_10', 'identifier': '1847194958'}], 'readingModes': {'text': False, 'image': True}, 'pageCount': 373, 'printType': 'BOOK', 'categories': ['Computers'], 'averageRating': 3.0, 'ratingsCount': 1, 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': True, 'contentVersion': '2.2.2.0.preview.1', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=9G9zX_jf1f8C&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=9G9zX_jf1f8C&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.co.in/books?id=9G9zX_jf1f8C&printsec=frontcover&dq=isbn:1847194958&hl=&cd=1&source=gbs_api', 'infoLink': 'https://play.google.com/store/books/details?id=9G9zX_jf1f8C&source=gbs_api', 'canonicalVolumeLink': 'https://market.android.com/details?id=book-9G9zX_jf1f8C'}
# {'google_url': 'https://market.android.com/details?id=book-5C_WBgAAQBAJ', 'description': 'If you are a GIS student or professional who needs an understanding of how to use ArcPy to reduce repetitive tasks and perform analysis faster, this book is for you. It is also a valuable book for Python programmers who want to understand how to automate geospatial analyses.', 'tags': ['Computers'], 'cover': 'http://books.google.com/books/content?id=5C_WBgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 'published_date': datetime.datetime(2015, 2, 26, 0, 0), 'publisher': 'Packt Publishing Ltd', 'authors': 'Silas Toms', 'page_count': 224, 'title': 'ArcPy and ArcGIS – Geospatial Analysis with Python'}
# {'title': 'ArcPy and ArcGIS – Geospatial Analysis with Python', 'authors': ['Silas Toms'], 'publisher': 'Packt Publishing Ltd', 'publishedDate': '2015-02-26', 'description': 'If you are a GIS student or professional who needs an understanding of how to use ArcPy to reduce repetitive tasks and perform analysis faster, this book is for you. It is also a valuable book for Python programmers who want to understand how to automate geospatial analyses.', 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781783988679'}, {'type': 'ISBN_10', 'identifier': '1783988673'}], 'readingModes': {'text': True, 'image': True}, 'pageCount': 224, 'printType': 'BOOK', 'categories': ['Computers'], 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': True, 'contentVersion': '2.2.2.0.preview.3', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=5C_WBgAAQBAJ&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=5C_WBgAAQBAJ&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.co.in/books?id=5C_WBgAAQBAJ&printsec=frontcover&dq=isbn:1783988673&hl=&cd=1&source=gbs_api', 'infoLink': 'https://play.google.com/store/books/details?id=5C_WBgAAQBAJ&source=gbs_api', 'canonicalVolumeLink': 'https://market.android.com/details?id=book-5C_WBgAAQBAJ'}
# {'google_url': 'https://books.google.com/books/about/Python.html?hl=&id=v2tFpwAACAAJ', 'description': "Daniel lives in fear of the school bully and his dad's pet python, but things change when the bully demands to see the snake.", 'tags': ['Adventure stories'], 'cover': 'http://books.google.com/books/content?id=v2tFpwAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api', 'published_date': datetime.datetime(2011, 9, 8, 0, 0), 'publisher': 'Caboodle', 'authors': 'Brian Moses', 'page_count': 144, 'title': 'Python'}
# {'title': 'Python', 'authors': ['Brian Moses'], 'publisher': 'Caboodle', 'publishedDate': '2011-09', 'description': "Daniel lives in fear of the school bully and his dad's pet python, but things change when the bully demands to see the snake.", 'industryIdentifiers': [{'type': 'ISBN_10', 'identifier': '0956948200'}, {'type': 'ISBN_13', 'identifier': '9780956948205'}], 'readingModes': {'text': False, 'image': False}, 'pageCount': 144, 'printType': 'BOOK', 'categories': ['Adventure stories'], 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': False, 'contentVersion': 'preview-1.0.0', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=v2tFpwAACAAJ&printsec=frontcover&img=1&zoom=5&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=v2tFpwAACAAJ&printsec=frontcover&img=1&zoom=1&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.co.in/books?id=v2tFpwAACAAJ&dq=isbn:0956948200&hl=&cd=1&source=gbs_api', 'infoLink': 'http://books.google.co.in/books?id=v2tFpwAACAAJ&dq=isbn:0956948200&hl=&source=gbs_api', 'canonicalVolumeLink': 'https://books.google.com/books/about/Python.html?hl=&id=v2tFpwAACAAJ'}
# {'google_url': 'https://market.android.com/details?id=book-UuQCkCWP86YC', 'description': '"You think too much! You mother F@$#%&* think too much! You\'re nothing but an arrogant, pointy-headed intellectual — I want you out of my classroom and off the premises in five minutes or I\'m calling the police and having you arrested for trespassing." — Hollywood acting teacher to Randy Olson, former scientist After nearly a decade on the defensive, the world of science is about to be restored to its rightful place. But is the American public really ready for science? And is the world of science ready for the American public? Scientists wear ragged clothes, forget to comb their hair, and speak in a language that even they don\'t understand. Or so people think. Most scientists don\'t care how they are perceived, but in our media-dominated age, style points count. Enter Randy Olson. Fifteen years ago, Olson bid farewell to the science world and shipped off to Hollywood ready to change the world. With films like Flock of Dodos: The Evolution-Intelligent Design Circus (Tribeca \'06, Showtime) and Sizzle: A Global Warming Comedy (Outfest \'08), he has tried to bridge the cultural divide that has too often left science on the outside looking in. Now, in his first book, Olson, with a Harvard Ph.D. and formerly a tenured professor of marine biology at the University of New Hampshire, recounts the lessons from his own hilarious-and at times humiliating-evolution from science professor to Hollywood filmmaker. In Don\'t Be Such a Scientist, he shares the secrets of talking substance in an age of style. The key, he argues, is to stay true to the facts while tapping into something more primordial, more irrational, and ultimately more human. In a book enlivened by a profane acting teacher who made Olson realize that "nobody wants to watch you think," he offers up serious insights and poignant stories. You\'ll laugh, you may cry, and as a communicator you\'ll certainly learn the importance of not only knowing how to fulfill, but also how to arouse.', 'tags': ['Science'], 'cover': 'http://books.google.com/books/content?id=UuQCkCWP86YC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api', 'published_date': datetime.datetime(2010, 5, 17, 0, 0), 'publisher': 'Island Press', 'authors': 'Randy Olson', 'page_count': 216, 'title': "Don't Be Such a Scientist"}
# {'title': "Don't Be Such a Scientist", 'subtitle': 'Talking Substance in an Age of Style', 'authors': ['Randy Olson'], 'publisher': 'Island Press', 'publishedDate': '2010-05-17', 'description': '"You think too much! You mother F@$#%&* think too much! You\'re nothing but an arrogant, pointy-headed intellectual — I want you out of my classroom and off the premises in five minutes or I\'m calling the police and having you arrested for trespassing." — Hollywood acting teacher to Randy Olson, former scientist After nearly a decade on the defensive, the world of science is about to be restored to its rightful place. But is the American public really ready for science? And is the world of science ready for the American public? Scientists wear ragged clothes, forget to comb their hair, and speak in a language that even they don\'t understand. Or so people think. Most scientists don\'t care how they are perceived, but in our media-dominated age, style points count. Enter Randy Olson. Fifteen years ago, Olson bid farewell to the science world and shipped off to Hollywood ready to change the world. With films like Flock of Dodos: The Evolution-Intelligent Design Circus (Tribeca \'06, Showtime) and Sizzle: A Global Warming Comedy (Outfest \'08), he has tried to bridge the cultural divide that has too often left science on the outside looking in. Now, in his first book, Olson, with a Harvard Ph.D. and formerly a tenured professor of marine biology at the University of New Hampshire, recounts the lessons from his own hilarious-and at times humiliating-evolution from science professor to Hollywood filmmaker. In Don\'t Be Such a Scientist, he shares the secrets of talking substance in an age of style. The key, he argues, is to stay true to the facts while tapping into something more primordial, more irrational, and ultimately more human. In a book enlivened by a profane acting teacher who made Olson realize that "nobody wants to watch you think," he offers up serious insights and poignant stories. You\'ll laugh, you may cry, and as a communicator you\'ll certainly learn the importance of not only knowing how to fulfill, but also how to arouse.', 'industryIdentifiers': [{'type': 'ISBN_13', 'identifier': '9781597267960'}, {'type': 'ISBN_10', 'identifier': '1597267961'}], 'readingModes': {'text': True, 'image': False}, 'pageCount': 216, 'printType': 'BOOK', 'categories': ['Science'], 'averageRating': 4.5, 'ratingsCount': 6, 'maturityRating': 'NOT_MATURE', 'allowAnonLogging': True, 'contentVersion': '0.4.4.0.preview.2', 'panelizationSummary': {'containsEpubBubbles': False, 'containsImageBubbles': False}, 'imageLinks': {'smallThumbnail': 'http://books.google.com/books/content?id=UuQCkCWP86YC&printsec=frontcover&img=1&zoom=5&edge=curl&source=gbs_api', 'thumbnail': 'http://books.google.com/books/content?id=UuQCkCWP86YC&printsec=frontcover&img=1&zoom=1&edge=curl&source=gbs_api'}, 'language': 'en', 'previewLink': 'http://books.google.co.in/books?id=UuQCkCWP86YC&printsec=frontcover&dq=isbn:1597267961&hl=&cd=1&source=gbs_api', 'infoLink': 'https://play.google.com/store/books/details?id=UuQCkCWP86YC&source=gbs_api', 'canonicalVolumeLink': 'https://market.android.com/details?id=book-UuQCkCWP86YC'}
